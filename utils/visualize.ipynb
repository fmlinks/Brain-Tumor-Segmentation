# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
del a0, a1, a2,a3,a4,a5,a6,a7

# %%
a0 = np.load('../data/X0.npy')
a0 = a0[:,:,:,3]
a1 = np.load('../results/VGG/0/vgg_test.npy')
a1 = np.squeeze(a1)
a2 = np.load('../results/DUnet/0/dunet_tfcv5.npy')
a3 = np.load('../results/FCNN/0/fcnn_tfcv5.npy')
a3 = np.squeeze(a3)
a4 = np.load('../results/PA+FP/0/paunet_tfcv5.npy')
a5 = np.load('../results/PA+FP+ED/0/paunet_tfcv5.npy')
a6 = np.load('../results/PA+EFP+ED/0/paunet_tfcv5.npy')
a7 = np.load('../data/Y0.npy')
a7 = np.argmax(a7, axis=3)

print(a0.shape,a1.shape,a2.shape,a3.shape,a4.shape,a5.shape,a6.shape,a7.shape)
# Out:
# (3784, 240, 240) (3784, 240, 240) (3784, 240, 240) (3784, 240, 240) (3784, 240, 240) (3784, 240, 240) (3784, 240, 240) (3784, 240, 240)

# %%
i = np.random.randint(0,3560)
# i = 124

print(i)
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.imshow(a7[i,:,:])
plt.title('Ground Truth', fontsize=30)

plt.subplot(1,3,2)
plt.imshow(a1[i,:,:])
plt.title('VGG', fontsize=30)
plt.subplot(1,3,3)
plt.imshow(a5[i,:,:])
plt.title('PA+FP+ED', fontsize=30)
plt.show()
# Out:
# 3159

# %%
# i = np.random.randint(0,3560)
i = 3159

print(i)
plt.figure(figsize=(20,11))



plt.subplot(2,4,1)
plt.imshow(a0[i,:,:])
plt.title('MRI', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,5)
plt.imshow(a7[i,:,:])
plt.title('Ground Truth', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,2)
plt.imshow(a1[i,:,:])
plt.title('VGG', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,3)
plt.imshow(a2[i,:,:])
plt.title('DUnet', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,4)
plt.imshow(a3[i,:,:])
plt.title('FCNN', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,6)
plt.imshow(a4[i,:,:])
plt.title('Ours(PA+FP)', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,7)
plt.imshow(a5[i,:,:])
plt.title('Ours(PA+FP+ED)', fontsize=20)
plt.xticks([])
plt.yticks([])

plt.subplot(2,4,8)
plt.imshow(a6[i,:,:])
plt.title('Ours(PA+EFP+ED)', fontsize=20)
plt.xticks([])
plt.yticks([])


plt.savefig('../results/figures/contrast_fig2_'+str(i)+'.eps')
plt.show()
# Out:
# 3159

# %%
# plt.savefig('../results/figures/contrast_fig_'+str(i)+'.eps')

# %%
# cite
1326
1461@@
1993
3429@
1462@@
2838@@

# %%
i = np.random.randint(0,3560)

plt.figure(figsize=(10, 10))

plt.imshow(a[i,:,:])


plt.show()
