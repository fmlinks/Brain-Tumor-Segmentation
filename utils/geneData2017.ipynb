# %%
import numpy as np
import matplotlib.pyplot as plt

path = './data/'

# %%
X0 = np.load(path + "./X0.npy")
Y0 = np.load(path + "./Y0.npy")
print('X0', np.shape(X0))
print('Y0', np.shape(Y0))
# Out:
# X0 (3836, 240, 240, 4)
# Y0 (3836, 240, 240, 4)

# %%
i = 2

a = X0[i,:,:,3]
b = Y0[i,:,:,1]
plt.subplot(1,2,1)
plt.imshow(a)
plt.subplot(1,2,2)
plt.imshow(b)
plt.show()

# %%
Y_test = Y0[2, :, :, 1]
print(1 in Y_test)
# Out:
# True

# %%
plt.imshow(Y_test)
plt.show()

# %%
number0 = np.sum(Y_test == 1)
print(number0)
# Out:
# 604

# %%
X0_new = []
Y0_new = []


for i in range(Y0.shape[0]):
    num = np.sum(Y0[i, :, :, 1] == 1)
    img_X = X0[i, :, :, :]
    img_Y = Y0[i, :, :, :]
    if num > 400:
        X0_new.append(img_X)
        Y0_new.append(img_Y)
        
    

print(np.shape(X0_new))
print(np.shape(Y0_new))
X0_new = np.array(X0_new)
Y0_new = np.array(Y0_new)
# Out:
# (3005, 240, 240, 4)
# (3005, 240, 240, 4)

# %%
X0_new = np.array(X0_new)
Y0_new = np.array(Y0_new)
print(np.shape(X0_new))
print(np.shape(Y0_new))
# Out:
# (3005, 240, 240, 4)
# (3005, 240, 240, 4)

# %%
i = 4

a = X0_new[i,:,:,3]
b = Y0_new[i,:,:,1]
plt.subplot(1,2,1)
plt.imshow(a)
plt.subplot(1,2,2)
plt.imshow(b)
plt.show()
